# %%
#Incluimos las instrucciones del juego
print("¡Bienvenida a Preguntas y Respuestas de Geografía!")
print("Tienes 3 intentos para responder cada pregunta correctamente")
print("Si fallas 3 preguntas habrás perdido. ¡Ten cuidado!")
print("Si aciertas 5 preguntas habrás ganado. ¡Mucha suerte!")
print("Empezamos")
# Out:
# ¡Bienvenida a Preguntas y Respuestas de Geografía!
# Tienes 3 intentos para responder cada pregunta correctamente
# Si fallas 3 preguntas habrás perdido. ¡Ten cuidado!
# Si aciertas 5 preguntas habrás ganado. ¡Mucha suerte!
# Empezamos

# %%
# Creamos un diccionario que contiene preguntas de geografía como claves y respuestas como valores
diccionario_preguntas = {"¿Cuál es el río más largo de la Península Ibérica?": "Tajo",                     "¿Cuál es el país más pequeño del mundo?": "Vaticano",
"¿Qué país del mundo en 2023 tenía más habitantes?": "India",
"¿Cuál es el río más largo del mundo?": "Nilo",
"¿Cuántos mares existen en la Tierra?": "60",
"¿Dónde podemos ver las auroras boreales?": "Polo Norte",
"¿Dónde podemos ver las auroras australes?": "Polo Sur",
"¿Qué río pasa por más paises?": "Danubio",  
"¿Cuál es la capital de España?": "Madrid",
"¿Cuántos países hay en el mundo? Por favor, introduce un número": "195",
"¿Cuál es el río más largo del mundo?": "Amazonas",
"¿Cuál es la montaña más alta de la Tierra?": "Everest",
"¿Cuántos océanos hay en el mundo? Por favor, introduce un número": "5",
"¿Qué país tiene la población más grande del mundo?": "China",
"¿Cuál es el desierto más grande del mundo?": "Sahara",
"¿Cuántos estados tiene Estados Unidos? Por favor, introduce un número": "50",
"¿Cuál es la capital de Australia?": "Canberra",
"¿Qué país es el más grande en términos de superficie terrestre?": "Rusia",
"¿Cuál es el lago más grande del mundo?": "Mar Caspio",
"¿En qué continente se encuentra Egipto?": "África",
"¿Cuál es la capital de Brasil?": "Brasilia",
"¿Qué país tiene la mayor cantidad de islas?": "Suecia",
"¿Cuántos habitantes tiene aproximadamente la Tierra? Por favor, introduce un número": "7800 millones",
"¿Cuál es la lengua oficial de Canadá?": "Inglés y francés",
"¿Cuál es la ciudad más poblada del mundo?": "Tokio",
"¿Cuál es la moneda oficial de la Unión Europea?": "Euro",
"¿Cuál es el país más pequeño del mundo?": "Vaticano",
"¿Cuál es el volcán más activo del mundo?": "Kilauea",}

valor = diccionario_preguntas ["¿Cuál es el río más largo de la Península Ibérica?"]
print(valor) #Comprobamos que devuelve la respuesta a la pregunta
# Out:
# Tajo

# %%
# Implementamos una función para seleccionar una pregunta aleatoria del diccionario.

import random #Importamos el módulo random

def seleccion_pregunta(diccionario):
    pregunta = random.choice(list(diccionario)) #Generamos una lista con las claves 
    #(preguntas) del diccionario y seleccionamos una de manera aleatoria. Lo 
    #almacenamos en la variable 'pregunta'
    return pregunta # Indicamos que lo que devuelve esta función es la variable pregunta

seleccion_pregunta(diccionario_preguntas) #Llamamos a la función con nuestro diccionario como 
#parámetro para comprobar que funciona
# Out:
# '¿Cuál es el desierto más grande del mundo?'

# %%
#Incluimos las instrucciones del juego
print("¡Bienvenida a Preguntas y Respuestas de Geografía!")
print("Tienes 3 intentos para responder cada pregunta correctamente")
print("Si fallas 3 preguntas habrás perdido. ¡Ten cuidado!")
print("Si aciertas 5 preguntas habrás ganado. ¡Mucha suerte!")
print("Empezamos")


# Creamos un diccionario que contiene preguntas de geografía como claves y respuestas como valores
diccionario_preguntas = {"¿Cuál es el río más largo de la Península Ibérica?": "Tajo",                     "¿Cuál es el país más pequeño del mundo?": "Vaticano",
"¿Qué país del mundo en 2023 tenía más habitantes?": "India",
"¿Cuál es el río más largo del mundo?": "Nilo",
"¿Cuántos mares existen en la Tierra?": "60",
"¿Dónde podemos ver las auroras boreales?": "Polo Norte",
"¿Dónde podemos ver las auroras australes?": "Polo Sur",
"¿Qué río pasa por más paises?": "Danubio",  
"¿Cuál es la capital de España?": "Madrid",
"¿Cuántos países hay en el mundo? Por favor, introduce un número": "195",
"¿Cuál es la montaña más alta de la Tierra?": "Everest",
"¿Cuántos océanos hay en el mundo? Por favor, introduce un número": "5",
"¿Qué país tiene la población más grande del mundo?": "China",
"¿Cuál es el desierto más grande del mundo?": "Sahara",
"¿Cuántos estados tiene Estados Unidos? Por favor, introduce un número": "50",
"¿Cuál es la capital de Australia?": "Canberra",
"¿Qué país es el más grande en términos de superficie terrestre?": "Rusia",
"¿Cuál es el lago más grande del mundo?": "Mar Caspio",
"¿En qué continente se encuentra Egipto?": "África",
"¿Cuál es la capital de Brasil?": "Brasilia",
"¿Qué país tiene la mayor cantidad de islas?": "Suecia",
"¿Cuántos habitantes tiene aproximadamente la Tierra? Por favor, introduce un número": "7800 millones",
"¿Cuál es la lengua oficial de Canadá?": "Inglés y francés",
"¿Cuál es la ciudad más poblada del mundo?": "Tokio",
"¿Cuál es la moneda oficial de la Unión Europea?": "Euro",
"¿Cuál es el país más pequeño del mundo?": "Vaticano",
"¿Cuál es el volcán más activo del mundo?": "Kilauea",}

import random #Importamos el módulo random para poder crear una función aleatoria

respuestas_correctas = 0 #Inicializamos la variable/contador respuestas_correctas
respuestas_incorrectas = 0 #Inicializamos la variable/contador respuestas_incorrectas
numero_intentos = 3 #Inicializamos la variable/contador numero_intentos
numero_preguntas = 0 #Inicializamos la variable/contador numero_preguntas


#Usamos un bucle while para que se ejecute mientras no alcancemos o 5 respuestas correctas o 3
#respuestas incorrectas     
while respuestas_correctas < 5 and respuestas_incorrectas < 3: 
    numero_preguntas +=1 #Actualizamos numero_preguntas sumando 1
    print('Pregunta', numero_preguntas) #Imprimimos el número de pregunta
    
    # Ejecutamos la función seleccion_regunta para que escoja una pregunta
    def seleccion_pregunta(diccionario):
        pregunta = random.choice(list(diccionario))
        return(pregunta)

    pregunta_seleccionada = seleccion_pregunta(diccionario_preguntas) #ejecutamos la función con el 
    #parámetro diccionario_preguntas y lo almacenamos en la variable pregunta _seleccionada
    print(pregunta_seleccionada) #Imprimimos la pregunta que ha seleccionado

    # Le presentamos la pregunta al usuario. Almacenamos su respuesta en la variable respuesta
    respuesta = input(f"{pregunta_seleccionada}")
    print(respuesta) #Imprimimos la respuesta del usuario
    
    # Comprobamos si la respuesta es correcta        
    if respuesta.strip().lower() == diccionario_preguntas[pregunta_seleccionada].strip().lower():
        print("¡Enhorabuena, acertaste!")
        respuestas_correctas += 1 #Actualizamos el número de respuestas correctas
        print(f"Llevas {respuestas_correctas} respuesta/s correcta/s") #Imprimimos las respuestas correctas que llevamos
        if respuestas_correctas == 5: #Si llegamos a 5 respuestas correctas imprimimos has ganado
            print('Enhorabuena!Has ganado el juego!')

    #Si la respuesta proporcionada es errónea    
    elif respuesta.strip().lower() != diccionario_preguntas[pregunta_seleccionada].strip().lower():
        while numero_intentos > 0: #Mientras nos quede más de un intento
            numero_intentos -= 1 #Actualizamos el número de intentos restantes quitando 1
            
            if numero_intentos > 0: #Si aun nos quedan intentos
                print(f"Lo siento. Has fallado. Inténtalo de nuevo. Te quedan {numero_intentos} intentos")
                print(pregunta_seleccionada) #Vuelve a imprimir la pregunta seleccionada y volvemos a 
                #ejecutar el bloque de código hasta comprobar si la respuesta es correcta
                respuesta = input(f"{pregunta_seleccionada}")
                print(respuesta)
                if respuesta.strip().lower() == diccionario_preguntas[pregunta_seleccionada].strip().lower():
                    print("¡Enhorabuena, acertaste!")
                    respuestas_correctas += 1
                    print(f"Llevas {respuestas_correctas} respuesta/s correcta/s")
                    numero_intentos = 3 #Iinicializamos el número de intentos una vez acertada la 
                    #respuesta
                    if respuestas_correctas == 5: #Cuando acertamos 5 preguntas imprimimos has ganado
                        print('Enhorabuena!Has ganado el juego!')
                    break    

            if numero_intentos == 0:  # En caso de que se hayan agotado los intentos               
                respuestas_incorrectas += 1 #Actualizamos el número de respuestas incorrectas
                print('Lo sentimos. Agotaste el número de intentos de esta pregunta')
                print(f'Has fallado {respuestas_incorrectas} pregunta/s')
                numero_intentos = 3 #Inicializamos el número de intentos una vez agotados todos los 
                #intentos
                if respuestas_incorrectas == 3: #Si fallamos 3 preguntas habremos perdido
                    print ('Lo siento. Has perdido. Juega de nuevo')
                break
# Out:
# ¡Bienvenida a Preguntas y Respuestas de Geografía!
# Tienes 3 intentos para responder cada pregunta correctamente
# Si fallas 3 preguntas habrás perdido. ¡Ten cuidado!
# Si aciertas 5 preguntas habrás ganado. ¡Mucha suerte!
# Empezamos
# Pregunta 1
# ¿Cuántos océanos hay en el mundo? Por favor, introduce un número
# 2
# Lo siento. Has fallado. Inténtalo de nuevo. Te quedan 2 intentos
# ¿Cuántos océanos hay en el mundo? Por favor, introduce un número
# 3
# Lo siento. Has fallado. Inténtalo de nuevo. Te quedan 1 intentos
# ¿Cuántos océanos hay en el mundo? Por favor, introduce un número
# 5
# ¡Enhorabuena, acertaste!
# Llevas 1 respuesta/s correcta/s
# Pregunta 2
# ¿Cuál es el río más largo de la Península Ibérica?
# duero
# Lo siento. Has fallado. Inténtalo de nuevo. Te quedan 2 intentos
# ¿Cuál es el río más largo de la Península Ibérica?
# tajo
# ¡Enhorabuena, acertaste!
# Llevas 2 respuesta/s correcta/s
# Pregunta 3
# ¿Cuántos países hay en el mundo? Por favor, introduce un número
# ...
